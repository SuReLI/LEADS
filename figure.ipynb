# %%
import wandb
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# plt.rcParams['text.usetex'] = True
import numpy as np
import seaborn as sns

# %%
wandb.login()
# Out:
# True

# %%
project_name = ['LDS_1', 'LDS_2', 'LDS_3']

all_runs_data = []

api = wandb.Api()
for prj_ne in project_name:
    runs = api.runs(prj_ne)
    for run in runs:
        metrics = run.history()
        run_data = {
            'run_id': run.id,
            'name': run.name,
            'config': run.config,
            'seed' : run.name.split('-')[-1],
            'metrics': metrics
        }
        all_runs_data.append(run_data)

# %%
# lds
Easy_lds_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'lds' in run_data['name']]
Ur_lds_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'lds' in run_data['name']]
Hard_lds_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'lds' in run_data['name']]
fetch_lds_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'lds' in run_data['name']]
finger_lds_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'lds' in run_data['name']]
fetch_push_lds_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'lds' in run_data['name']]
hopper_lds_data = [ run_data for run_data in all_runs_data if 'hopper' in run_data['name'] and 'lds' in run_data['name']]
# diayn
Easy_diayn_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'diayn' in run_data['name']]
Ur_diayn_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'diayn' in run_data['name']]
Hard_diayn_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'diayn' in run_data['name']]
fetch_diayn_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'diayn' in run_data['name']]
finger_diayn_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'diayn' in run_data['name']]
fetch_push_diayn_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'diayn' in run_data['name']]
hopper_diayn_data = [ run_data for run_data in all_runs_data if 'hopper' in run_data['name'] and 'diayn' in run_data['name']]
# rnd 
Easy_rnd_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'rnd' in run_data['name']]
Ur_rnd_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'rnd' in run_data['name']]
Hard_rnd_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'rnd' in run_data['name']]
fetch_rnd_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'rnd' in run_data['name']]
finger_rnd_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'rnd' in run_data['name']]
fetch_push_rnd_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'rnd' in run_data['name']]
hopper_rnd_data = [ run_data for run_data in all_runs_data if 'hopper' in run_data['name'] and 'rnd' in run_data['name']]
# ngu
Easy_ngu_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'ngu' in run_data['name']]
Ur_ngu_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'ngu' in run_data['name']]
Hard_ngu_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'ngu' in run_data['name']]
fetch_ngu_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'ngu' in run_data['name']]
finger_ngu_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'ngu' in run_data['name']]
fetch_push_ngu_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'ngu' in run_data['name']]
hopper_ngu_data = [ run_data for run_data in all_runs_data if 'hopper' in run_data['name'] and 'ngu' in run_data['name']]
# lsd
Easy_lsd_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'lsd' in run_data['name']]
Ur_lsd_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'lsd' in run_data['name']]
Hard_lsd_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'lsd' in run_data['name']]
fetch_lsd_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'lsd' in run_data['name']]
finger_lsd_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'lsd' in run_data['name']]
fetch_push_lsd_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'lsd' in run_data['name']]
hopper_lsd_data = [ run_data for run_data in all_runs_data if 'hopper' in run_data['name'] and 'lsd' in run_data['name']]
# csd 
Easy_csd_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'csd' in run_data['name']]
Ur_csd_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'csd' in run_data['name']]
Hard_csd_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'csd' in run_data['name']]
fetch_csd_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'csd' in run_data['name']]
finger_csd_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'csd' in run_data['name']]
fetch_push_csd_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'csd' in run_data['name']]
# metra
Easy_metra_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'metra' in run_data['name']]
Ur_metra_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'metra' in run_data['name']]
Hard_metra_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'metra' in run_data['name']]
fetch_metra_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'metra' in run_data['name']]
finger_metra_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'metra' in run_data['name']]
fetch_push_metra_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'metra' in run_data['name']]
# smm
Easy_smm_data = [ run_data for run_data in all_runs_data if 'Easy' in run_data['name']and 'smm' in run_data['name']]
Ur_smm_data = [ run_data for run_data in all_runs_data if 'Ur' in run_data['name'] and 'smm' in run_data['name']]
Hard_smm_data = [ run_data for run_data in all_runs_data if 'Hard' in run_data['name'] and 'smm' in run_data['name']]
fetch_smm_data = [ run_data for run_data in all_runs_data if 'fetch' in run_data['name'] and 'smm' in run_data['name']]
finger_smm_data = [ run_data for run_data in all_runs_data if 'finger' in run_data['name'] and 'smm' in run_data['name']]
fetch_push_smm_data = [ run_data for run_data in all_runs_data if 'fetch_push' in run_data['name'] and 'smm' in run_data['name']]

# %%
def fill_to_size(arr, size):
    """ fill array to size with last element """
    arr = np.expand_dims(arr, axis=1)
    while len(arr) < size:
        arr = np.vstack([arr, arr[-1]])
    return arr

# %%
# env to do
list_env = ['Easy', 'Ur', 'Hard', 'fetch', 'finger', 'fetch_push']
list_alg = ['lds', 'diayn', 'rnd', 'ngu', 'lsd', 'csd', 'metra', 'smm']

# %%
# lds
Easy_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_lds_data]) if 'Easy' in list_env and 'lds' in list_alg else None
Ur_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_lds_data]) if 'Ur' in list_env and 'lds' in list_alg else None
Hard_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_lds_data]) if 'Hard' in list_env and 'lds' in list_alg else None
fetch_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_lds_data]) if 'fetch' in list_env and 'lds' in list_alg else None
finger_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_lds_data]) if 'finger' in list_env and 'lds' in list_alg else None
fetch_push_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_lds_data]) if 'fetch_push' in list_env and 'lds' in list_alg else None
hopper_lds_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in hopper_lds_data]) if 'hopper' in list_env and 'lds' in list_alg else None
# diayn
Easy_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_diayn_data]) if 'Easy' in list_env and 'diayn' in list_alg else None
Ur_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_diayn_data]) if 'Ur' in list_env and 'diayn' in list_alg else None
Hard_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_diayn_data]) if 'Hard' in list_env and 'diayn' in list_alg else None
fetch_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_diayn_data]) if 'fetch' in list_env and 'diayn' in list_alg else None
finger_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_diayn_data]) if 'finger' in list_env and 'diayn' in list_alg  else None
fetch_push_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_diayn_data]) if 'fetch_push' in list_env and 'diayn' in list_alg  else None
hopper_diayn_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in hopper_diayn_data]) if 'hopper' in list_env and 'diayn' in list_alg  else None
# rnd
Easy_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_rnd_data]) if 'Easy' in list_env and 'rnd' in list_alg  else None
Ur_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_rnd_data]) if 'Ur' in list_env and 'rnd' in list_alg  else None
Hard_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_rnd_data]) if 'Hard' in list_env and 'rnd' in list_alg  else None
fetch_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_rnd_data]) if 'fetch' in list_env and 'rnd' in list_alg  else None
finger_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_rnd_data]) if 'finger' in list_env and 'rnd' in list_alg  else None
fetch_push_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_rnd_data]) if 'fetch_push' in list_env and 'rnd' in list_alg  else None
hopper_rnd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in hopper_rnd_data]) if 'hopper' in list_env and 'rnd' in list_alg  else None
# ngu 
Easy_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_ngu_data]) if 'Easy' in list_env and 'ngu' in list_alg  else None
Ur_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_ngu_data]) if 'Ur' in list_env and 'ngu' in list_alg  else None
Hard_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_ngu_data]) if 'Hard' in list_env and 'ngu' in list_alg  else None
fetch_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_ngu_data]) if 'fetch' in list_env and 'ngu' in list_alg  else None
finger_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_ngu_data]) if 'finger' in list_env and 'ngu' in list_alg  else None
fetch_push_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_ngu_data]) if 'fetch_push' in list_env and 'ngu' in list_alg  else None
hopper_ngu_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in hopper_ngu_data]) if 'hopper' in list_env and 'ngu' in list_alg  else None
# lsd
Easy_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_lsd_data]) if 'Easy' in list_env and 'lsd' in list_alg  else None
Ur_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_lsd_data]) if 'Ur' in list_env and 'lsd' in list_alg  else None
Hard_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_lsd_data]) if 'Hard' in list_env and 'lsd' in list_alg  else None
fetch_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_lsd_data]) if 'fetch' in list_env and 'lsd' in list_alg  else None
finger_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_lsd_data]) if 'finger' in list_env and 'lsd' in list_alg  else None
fetch_push_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_lsd_data]) if 'fetch_push' in list_env and 'lsd' in list_alg  else None
hopper_lsd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in hopper_lsd_data]) if 'hopper' in list_env and 'lsd' in list_alg  else None
# csd
Easy_csd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_csd_data]) if 'Easy' in list_env and 'csd' in list_alg  else None
Ur_csd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_csd_data]) if 'Ur' in list_env and 'csd' in list_alg  else None
Hard_csd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_csd_data]) if 'Hard' in list_env and 'csd' in list_alg  else None
fetch_csd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_csd_data]) if 'fetch' in list_env and 'csd' in list_alg  else None
finger_csd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_csd_data]) if 'finger' in list_env and 'csd' in list_alg  else None
fetch_push_csd_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_csd_data]) if 'fetch_push' in list_env and 'csd' in list_alg  else None
# metra
Easy_metra_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_metra_data]) if 'Easy' in list_env and 'metra' in list_alg  else None
Ur_metra_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_metra_data]) if 'Ur' in list_env and 'metra' in list_alg  else None
Hard_metra_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_metra_data]) if 'Hard' in list_env and 'metra' in list_alg  else None
fetch_metra_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_metra_data]) if 'fetch' in list_env and 'metra' in list_alg  else None
finger_metra_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_metra_data]) if 'finger' in list_env and 'metra' in list_alg  else None
fetch_push_metra_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_metra_data]) if 'fetch_push' in list_env and 'metra' in list_alg  else None
# smm
Easy_smm_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Easy_smm_data]) if 'Easy' in list_env and 'smm' in list_alg  else None
Ur_smm_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Ur_smm_data]) if 'Ur' in list_env and 'smm' in list_alg  else None
Hard_smm_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in Hard_smm_data]) if 'Hard' in list_env and 'smm' in list_alg  else None
fetch_smm_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_smm_data]) if 'fetch' in list_env and 'smm' in list_alg  else None
finger_smm_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in finger_smm_data]) if 'finger' in list_env and 'smm' in list_alg  else None
fetch_push_smm_max_step = max([len(run_data['metrics']['coverage']) if 'coverage' in run_data['metrics'].keys() else None  for run_data in fetch_push_smm_data]) if 'fetch_push' in list_env and 'smm' in list_alg  else None

# %%
def delete_none(liste):
    return list(filter(None.__ne__, liste))

# %%
Easy_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_lds_data]), axis=1) if 'Easy' in list_env and 'lds' in list_alg else None
Ur_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_lds_data]), axis=1) if 'Ur' in list_env and 'lds' in list_alg else None
Hard_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_lds_data]), axis=1) if 'Hard' in list_env and 'lds' in list_alg else None    
fetch_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_lds_data]), axis=1) if 'fetch' in list_env and 'lds' in list_alg else None 
finger_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_lds_data]), axis=1) if 'finger' in list_env and 'lds' in list_alg else None
fetch_push_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_lds_data]), axis=1) if 'fetch_push' in list_env and 'lds' in list_alg else None
hopper_lds_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, hopper_lds_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in hopper_lds_data]), axis=1) if 'hopper' in list_env and 'lds' in list_alg else None
# diayn
Easy_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_diayn_data]), axis=1) if 'Easy' in list_env and 'diayn' in list_alg else None
Ur_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_diayn_data]), axis=1) if 'Ur' in list_env and 'diayn' in list_alg else None
Hard_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_diayn_data]), axis=1) if 'Hard' in list_env and 'diayn' in list_alg else None
fetch_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_diayn_data]), axis=1) if 'fetch' in list_env and 'diayn' in list_alg else None
finger_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_diayn_data]), axis=1) if 'finger' in list_env and 'diayn' in list_alg else None
fetch_push_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_diayn_data]), axis=1) if 'fetch_push' in list_env and 'diayn' in list_alg else None
hopper_diayn_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, hopper_diayn_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in hopper_diayn_data]), axis=1) if 'hopper' in list_env and 'diayn' in list_alg else None
# rnd
Easy_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_rnd_data]), axis=1) if 'Easy' in list_env and 'rnd' in list_alg else None
Ur_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_rnd_data]), axis=1) if 'Ur' in list_env and 'rnd' in list_alg else None
Hard_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_rnd_data]), axis=1) if 'Hard' in list_env and 'rnd' in list_alg else None
fetch_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_rnd_data]), axis=1) if 'fetch' in list_env and 'rnd' in list_alg else None
finger_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_rnd_data]), axis=1) if 'finger' in list_env and 'rnd' in list_alg else None
fetch_push_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_rnd_data]), axis=1) if 'fetch_push' in list_env and 'rnd' in list_alg else None
hopper_rnd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, hopper_rnd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in hopper_rnd_data]), axis=1) if 'hopper' in list_env and 'rnd' in list_alg else None
# ngu
Easy_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_ngu_data]), axis=1) if 'Easy' in list_env and 'ngu' in list_alg else None
Ur_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_ngu_data]), axis=1) if 'Ur' in list_env and 'ngu' in list_alg else None
Hard_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_ngu_data]), axis=1) if 'Hard' in list_env and 'ngu' in list_alg else None
fetch_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_ngu_data]), axis=1) if 'fetch' in list_env and 'ngu' in list_alg else None
finger_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_ngu_data]), axis=1) if 'finger' in list_env and 'ngu' in list_alg else None
fetch_push_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_ngu_data]), axis=1) if 'fetch_push' in list_env and 'ngu' in list_alg else None
hopper_ngu_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, hopper_ngu_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in hopper_ngu_data]), axis=1) if 'hopper' in list_env and 'ngu' in list_alg else None
# lsd
Easy_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_lsd_data]), axis=1) if 'Easy' in list_env and 'lsd' in list_alg else None
Ur_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_lsd_data]), axis=1) if 'Ur' in list_env and 'lsd' in list_alg else None
Hard_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_lsd_data]), axis=1) if 'Hard' in list_env and 'lsd' in list_alg else None
fetch_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_lsd_data]), axis=1) if 'fetch' in list_env and 'lsd' in list_alg else None
finger_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_lsd_data]), axis=1) if 'finger' in list_env and 'lsd' in list_alg else None
fetch_push_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_lsd_data]), axis=1) if 'fetch_push' in list_env and 'lsd' in list_alg else None
hopper_lsd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, hopper_lsd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in hopper_lsd_data]), axis=1) if 'hopper' in list_env and 'lsd' in list_alg else None
# csd
Easy_csd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_csd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_csd_data]), axis=1) if 'Easy' in list_env and 'csd' in list_alg else None
Ur_csd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_csd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_csd_data]), axis=1) if 'Ur' in list_env and 'csd' in list_alg else None
Hard_csd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_csd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_csd_data]), axis=1) if 'Hard' in list_env and 'csd' in list_alg else None
fetch_csd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_csd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_csd_data]), axis=1) if 'fetch' in list_env and 'csd' in list_alg else None
finger_csd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_csd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_csd_data]), axis=1) if 'finger' in list_env and 'csd' in list_alg else None
fetch_push_csd_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_csd_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_csd_data]), axis=1) if 'fetch_push' in list_env and 'csd' in list_alg else None
# metra
Easy_metra_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_metra_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_metra_data]), axis=1) if 'Easy' in list_env and 'metra' in list_alg else None
Ur_metra_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_metra_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_metra_data]), axis=1) if 'Ur' in list_env and 'metra' in list_alg else None
Hard_metra_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_metra_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_metra_data]), axis=1) if 'Hard' in list_env and 'metra' in list_alg else None
fetch_metra_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_metra_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_metra_data]), axis=1) if 'fetch' in list_env and 'metra' in list_alg else None
finger_metra_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_metra_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_metra_data]), axis=1) if 'finger' in list_env and 'metra' in list_alg else None
fetch_push_metra_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_metra_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_metra_data]), axis=1) if 'fetch_push' in list_env and 'metra' in list_alg else None
# smm
Easy_smm_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Easy_smm_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Easy_smm_data]), axis=1) if 'Easy' in list_env and 'smm' in list_alg else None
Ur_smm_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Ur_smm_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Ur_smm_data]), axis=1) if 'Ur' in list_env and 'smm' in list_alg else None
Hard_smm_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, Hard_smm_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in Hard_smm_data]), axis=1) if 'Hard' in list_env and 'smm' in list_alg else None
fetch_smm_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_smm_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_smm_data]), axis=1) if 'fetch' in list_env and 'smm' in list_alg else None
finger_smm_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, finger_smm_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in finger_smm_data]), axis=1) if 'finger' in list_env and 'smm' in list_alg else None
fetch_push_smm_coverage_stack = np.concatenate(delete_none([fill_to_size(run_data['metrics']['coverage'].values, fetch_push_smm_max_step) if 'coverage' in run_data['metrics'].keys() else None for run_data in fetch_push_smm_data]), axis=1) if 'fetch_push' in list_env and 'smm' in list_alg else None
# Out:
# /tmp/ipykernel_7743/1915478931.py:2: DeprecationWarning: NotImplemented should not be used in a boolean context
#   return list(filter(None.__ne__, liste))

# %%
nb_runs = 5

# %%
# mean and std 
# lds
Easy_lds_coverage_mean = np.mean(Easy_lds_coverage_stack, axis=1) if 'Easy' in list_env and 'lds' in list_alg else None
Easy_lds_coverage_std = np.std(Easy_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'lds' in list_alg else None
Ur_lds_coverage_mean = np.mean(Ur_lds_coverage_stack, axis=1) if 'Ur' in list_env and 'lds' in list_alg else None
Ur_lds_coverage_std = np.std(Ur_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'lds' in list_alg else None
Hard_lds_coverage_mean = np.mean(Hard_lds_coverage_stack, axis=1) if 'Hard' in list_env and 'lds' in list_alg else None
Hard_lds_coverage_std = np.std(Hard_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'lds' in list_alg else None
fetch_lds_coverage_std = np.std(fetch_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'lds' in list_alg else None
fetch_lds_coverage_mean = np.mean(fetch_lds_coverage_stack, axis=1) if 'fetch' in list_env and 'lds' in list_alg else None
finger_lds_coverage_mean = np.mean(finger_lds_coverage_stack, axis=1) if 'finger' in list_env and 'lds' in list_alg else None
finger_lds_coverage_std = np.std(finger_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'lds' in list_alg else None
fetch_push_lds_coverage_mean = np.mean(fetch_push_lds_coverage_stack, axis=1) if 'fetch_push' in list_env and 'lds' in list_alg else None
fetch_push_lds_coverage_std = np.std(fetch_push_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'lds' in list_alg else None
hopper_lds_coverage_mean = np.mean(hopper_lds_coverage_stack, axis=1) if 'hopper' in list_env and 'lds' in list_alg else None
hopper_lds_coverage_std = np.std(hopper_lds_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'hopper' in list_env and 'lds' in list_alg else None
# diayn 
Easy_diayn_coverage_mean = np.mean(Easy_diayn_coverage_stack, axis=1) if 'Easy' in list_env and 'diayn' in list_alg else None
Easy_diayn_coverage_std = np.std(Easy_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'diayn' in list_alg else None
Ur_diayn_coverage_mean = np.mean(Ur_diayn_coverage_stack, axis=1) if 'Ur' in list_env and 'diayn' in list_alg else None
Ur_diayn_coverage_std = np.std(Ur_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'diayn' in list_alg else None
Hard_diayn_coverage_mean = np.mean(Hard_diayn_coverage_stack, axis=1) if 'Hard' in list_env and 'diayn' in list_alg else None
Hard_diayn_coverage_std = np.std(Hard_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'diayn' in list_alg else None
fetch_diayn_coverage_std = np.std(fetch_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'diayn' in list_alg else None
fetch_diayn_coverage_mean = np.mean(fetch_diayn_coverage_stack, axis=1) if 'fetch' in list_env and 'diayn' in list_alg else None
finger_diayn_coverage_mean = np.mean(finger_diayn_coverage_stack, axis=1) if 'finger' in list_env and 'diayn' in list_alg else None
finger_diayn_coverage_std = np.std(finger_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs)   if 'finger' in list_env and 'diayn' in list_alg else None
fetch_push_diayn_coverage_mean = np.mean(fetch_push_diayn_coverage_stack, axis=1) if 'fetch_push' in list_env and 'diayn' in list_alg else None
fetch_push_diayn_coverage_std = np.std(fetch_push_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'diayn' in list_alg else None
hopper_diayn_coverage_mean = np.mean(hopper_diayn_coverage_stack, axis=1) if 'hopper' in list_env and 'diayn' in list_alg else None
hopper_diayn_coverage_std = np.std(hopper_diayn_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'hopper' in list_env and 'diayn' in list_alg else None
# rnd
Easy_rnd_coverage_mean = np.mean(Easy_rnd_coverage_stack, axis=1)[:150] if 'Easy' in list_env and 'rnd' in list_alg else None
Easy_rnd_coverage_std = np.std(Easy_rnd_coverage_stack, axis=1)[:150]/np.sqrt(nb_runs) if 'Easy' in list_env and 'rnd' in list_alg else None
Ur_rnd_coverage_mean = np.mean(Ur_rnd_coverage_stack, axis=1)[:150] if 'Ur' in list_env and 'rnd' in list_alg else None
Ur_rnd_coverage_std = np.std(Ur_rnd_coverage_stack, axis=1)[:150]/np.sqrt(nb_runs) if 'Ur' in list_env and 'rnd' in list_alg else None
Hard_rnd_coverage_mean = np.mean(Hard_rnd_coverage_stack, axis=1)[:150] if 'Hard' in list_env and 'rnd' in list_alg else None
Hard_rnd_coverage_std = np.std(Hard_rnd_coverage_stack, axis=1)[:150]/np.sqrt(nb_runs) if 'Hard' in list_env and 'rnd' in list_alg else None
fetch_rnd_coverage_std = np.std(fetch_rnd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'rnd' in list_alg else None
fetch_rnd_coverage_mean = np.mean(fetch_rnd_coverage_stack, axis=1) if 'fetch' in list_env and 'rnd' in list_alg else None
finger_rnd_coverage_mean = np.mean(finger_rnd_coverage_stack, axis=1) if 'finger' in list_env and 'rnd' in list_alg else None
finger_rnd_coverage_std = np.std(finger_rnd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'rnd' in list_alg else None
fetch_push_rnd_coverage_mean = np.mean(fetch_push_rnd_coverage_stack, axis=1) if 'fetch_push' in list_env and 'rnd' in list_alg else None
fetch_push_rnd_coverage_std = np.std(fetch_push_rnd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'rnd' in list_alg else None
hopper_rnd_coverage_mean = np.mean(hopper_rnd_coverage_stack, axis=1) if 'hopper' in list_env and 'rnd' in list_alg else None
hopper_rnd_coverage_std = np.std(hopper_rnd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'hopper' in list_env and 'rnd' in list_alg else None
# ngu
Easy_ngu_coverage_mean = np.mean(Easy_ngu_coverage_stack, axis=1) if 'Easy' in list_env and 'ngu' in list_alg else None
Easy_ngu_coverage_std = np.std(Easy_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'ngu' in list_alg else None
Ur_ngu_coverage_mean = np.mean(Ur_ngu_coverage_stack, axis=1) if 'Ur' in list_env and 'ngu' in list_alg else None
Ur_ngu_coverage_std = np.std(Ur_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'ngu' in list_alg else None
Hard_ngu_coverage_mean = np.mean(Hard_ngu_coverage_stack, axis=1) if 'Hard' in list_env and 'ngu' in list_alg else None
Hard_ngu_coverage_std = np.std(Hard_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'ngu' in list_alg else None
fetch_ngu_coverage_std = np.std(fetch_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'ngu' in list_alg else None
fetch_ngu_coverage_mean = np.mean(fetch_ngu_coverage_stack, axis=1) if 'fetch' in list_env and 'ngu' in list_alg else None
finger_ngu_coverage_mean = np.mean(finger_ngu_coverage_stack, axis=1) if 'finger' in list_env and 'ngu' in list_alg else None
finger_ngu_coverage_std = np.std(finger_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'ngu' in list_alg else None
fetch_push_ngu_coverage_mean = np.mean(fetch_push_ngu_coverage_stack, axis=1) if 'fetch_push' in list_env and 'ngu' in list_alg else None
fetch_push_ngu_coverage_std = np.std(fetch_push_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'ngu' in list_alg else None
hopper_ngu_coverage_mean = np.mean(hopper_ngu_coverage_stack, axis=1) if 'hopper' in list_env and 'ngu' in list_alg else None
hopper_ngu_coverage_std = np.std(hopper_ngu_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'hopper' in list_env and 'ngu' in list_alg else None
# lsd
Easy_lsd_coverage_mean = np.mean(Easy_lsd_coverage_stack, axis=1) if 'Easy' in list_env and 'lsd' in list_alg else None
Easy_lsd_coverage_std = np.std(Easy_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'lsd' in list_alg else None
Ur_lsd_coverage_mean = np.mean(Ur_lsd_coverage_stack, axis=1) if 'Ur' in list_env and 'lsd' in list_alg else None
Ur_lsd_coverage_std = np.std(Ur_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'lsd' in list_alg else None
Hard_lsd_coverage_mean = np.mean(Hard_lsd_coverage_stack, axis=1) if 'Hard' in list_env and 'lsd' in list_alg else None
Hard_lsd_coverage_std = np.std(Hard_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'lsd' in list_alg else None
fetch_lsd_coverage_std = np.std(fetch_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'lsd' in list_alg else None
fetch_lsd_coverage_mean = np.mean(fetch_lsd_coverage_stack, axis=1) if 'fetch' in list_env and 'lsd' in list_alg else None
finger_lsd_coverage_mean = np.mean(finger_lsd_coverage_stack, axis=1) if 'finger' in list_env and 'lsd' in list_alg else None
finger_lsd_coverage_std = np.std(finger_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'lsd' in list_alg else None
fetch_push_lsd_coverage_mean = np.mean(fetch_push_lsd_coverage_stack, axis=1) if 'fetch_push' in list_env and 'lsd' in list_alg else None
fetch_push_lsd_coverage_std = np.std(fetch_push_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'lsd' in list_alg else None
hopper_lsd_coverage_mean = np.mean(hopper_lsd_coverage_stack, axis=1) if 'hopper' in list_env and 'lsd' in list_alg else None
hopper_lsd_coverage_std = np.std(hopper_lsd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'hopper' in list_env and 'lsd' in list_alg else None
# csd
Easy_csd_coverage_mean = np.mean(Easy_csd_coverage_stack, axis=1) if 'Easy' in list_env and 'csd' in list_alg else None
Easy_csd_coverage_std = np.std(Easy_csd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'csd' in list_alg else None
Ur_csd_coverage_mean = np.mean(Ur_csd_coverage_stack, axis=1) if 'Ur' in list_env and 'csd' in list_alg else None
Ur_csd_coverage_std = np.std(Ur_csd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'csd' in list_alg else None
Hard_csd_coverage_mean = np.mean(Hard_csd_coverage_stack, axis=1) if 'Hard' in list_env and 'csd' in list_alg else None
Hard_csd_coverage_std = np.std(Hard_csd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'csd' in list_alg else None
fetch_csd_coverage_std = np.std(fetch_csd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'csd' in list_alg else None
fetch_csd_coverage_mean = np.mean(fetch_csd_coverage_stack, axis=1) if 'fetch' in list_env and 'csd' in list_alg else None
finger_csd_coverage_mean = np.mean(finger_csd_coverage_stack, axis=1) if 'finger' in list_env and 'csd' in list_alg else None
finger_csd_coverage_std = np.std(finger_csd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'csd' in list_alg else None
fetch_push_csd_coverage_mean = np.mean(fetch_push_csd_coverage_stack, axis=1) if 'fetch_push' in list_env and 'csd' in list_alg else None
fetch_push_csd_coverage_std = np.std(fetch_push_csd_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'csd' in list_alg else None
# metra
Easy_metra_coverage_mean = np.mean(Easy_metra_coverage_stack, axis=1) if 'Easy' in list_env and 'metra' in list_alg else None
Easy_metra_coverage_std = np.std(Easy_metra_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'metra' in list_alg else None
Ur_metra_coverage_mean = np.mean(Ur_metra_coverage_stack, axis=1) if 'Ur' in list_env and 'metra' in list_alg else None
Ur_metra_coverage_std = np.std(Ur_metra_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'metra' in list_alg else None
Hard_metra_coverage_mean = np.mean(Hard_metra_coverage_stack, axis=1) if 'Hard' in list_env and 'metra' in list_alg else None
Hard_metra_coverage_std = np.std(Hard_metra_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'metra' in list_alg else None
fetch_metra_coverage_std = np.std(fetch_metra_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'metra' in list_alg else None
fetch_metra_coverage_mean = np.mean(fetch_metra_coverage_stack, axis=1) if 'fetch' in list_env and 'metra' in list_alg else None
finger_metra_coverage_mean = np.mean(finger_metra_coverage_stack, axis=1) if 'finger' in list_env and 'metra' in list_alg else None
finger_metra_coverage_std = np.std(finger_metra_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'metra' in list_alg else None
fetch_push_metra_coverage_mean = np.mean(fetch_push_metra_coverage_stack, axis=1) if 'fetch_push' in list_env and 'metra' in list_alg else None
fetch_push_metra_coverage_std = np.std(fetch_push_metra_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'metra' in list_alg else None
# smm
Easy_smm_coverage_mean = np.mean(Easy_smm_coverage_stack, axis=1) if 'Easy' in list_env and 'smm' in list_alg else None
Easy_smm_coverage_std = np.std(Easy_smm_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Easy' in list_env and 'smm' in list_alg else None
Ur_smm_coverage_mean = np.mean(Ur_smm_coverage_stack, axis=1) if 'Ur' in list_env and 'smm' in list_alg else None
Ur_smm_coverage_std = np.std(Ur_smm_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Ur' in list_env and 'smm' in list_alg else None
Hard_smm_coverage_mean = np.mean(Hard_smm_coverage_stack, axis=1) if 'Hard' in list_env and 'smm' in list_alg else None
Hard_smm_coverage_std = np.std(Hard_smm_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'Hard' in list_env and 'smm' in list_alg else None
fetch_smm_coverage_std = np.std(fetch_smm_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch' in list_env and 'smm' in list_alg else None
fetch_smm_coverage_mean = np.mean(fetch_smm_coverage_stack, axis=1) if 'fetch' in list_env and 'smm' in list_alg else None
finger_smm_coverage_mean = np.mean(finger_smm_coverage_stack, axis=1) if 'finger' in list_env and 'smm' in list_alg else None
finger_smm_coverage_std = np.std(finger_smm_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'finger' in list_env and 'smm' in list_alg else None
fetch_push_smm_coverage_mean = np.mean(fetch_push_smm_coverage_stack, axis=1) if 'fetch_push' in list_env and 'smm' in list_alg else None
fetch_push_smm_coverage_std = np.std(fetch_push_smm_coverage_stack, axis=1)/np.sqrt(nb_runs) if 'fetch_push' in list_env and 'smm' in list_alg else None

# %%
# tar 
if 'Easy' in list_env and 'lds' in list_alg : 
    Easy_lds_coverage_mean[0] = 0
if 'Ur' in list_env and 'lds' in list_alg : 
    Ur_lds_coverage_mean[0] = 0
if 'Hard' in list_env and 'lds' in list_alg : 
    Hard_lds_coverage_mean[0] = 0
if 'fetch' in list_env and 'lds' in list_alg : 
    fetch_lds_coverage_mean[0] = 0
if 'finger' in list_env and 'lds' in list_alg : 
    finger_lds_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'lds' in list_alg : 
    fetch_push_lds_coverage_mean[0] = 0
if 'hopper' in list_env and 'lds' in list_alg : 
    hopper_lds_coverage_mean[0] = 0
# diayn
if 'Easy' in list_env and 'diayn' in list_alg : 
    Easy_diayn_coverage_mean[0] = 0
if 'Ur' in list_env and 'diayn' in list_alg : 
    Ur_diayn_coverage_mean[0] = 0
if 'Hard' in list_env and 'diayn' in list_alg : 
    Hard_diayn_coverage_mean[0] = 0
if 'fetch' in list_env and 'diayn' in list_alg : 
    fetch_diayn_coverage_mean[0] = 0
if 'finger' in list_env and 'diayn' in list_alg : 
    finger_diayn_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'diayn' in list_alg : 
    fetch_push_diayn_coverage_mean[0] = 0
if 'hopper' in list_env and 'diayn' in list_alg : 
    hopper_diayn_coverage_mean[0] = 0

# rnd
if 'Easy' in list_env and 'rnd' in list_alg : 
    Easy_rnd_coverage_mean[0] = 0
if 'Ur' in list_env and 'rnd' in list_alg : 
    Ur_rnd_coverage_mean[0] = 0
if 'Hard' in list_env and 'rnd' in list_alg : 
    Hard_rnd_coverage_mean[0] = 0
if 'fetch' in list_env and 'rnd' in list_alg : 
    fetch_rnd_coverage_mean[0] = 0
if 'finger' in list_env and 'rnd' in list_alg : 
    finger_rnd_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'rnd' in list_alg : 
    fetch_push_rnd_coverage_mean[0] = 0
if 'hopper' in list_env and 'rnd' in list_alg : 
    hopper_rnd_coverage_mean[0] = 0
# ngu
if 'Easy' in list_env and 'ngu' in list_alg : 
    Easy_ngu_coverage_mean[0] = 0
if 'Ur' in list_env and 'ngu' in list_alg : 
    Ur_ngu_coverage_mean[0] = 0
if 'Hard' in list_env and 'ngu' in list_alg : 
    Hard_ngu_coverage_mean[0] = 0
if 'fetch' in list_env and 'ngu' in list_alg : 
    fetch_ngu_coverage_mean[0] = 0
if 'finger' in list_env and 'ngu' in list_alg : 
    finger_ngu_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'ngu' in list_alg : 
    fetch_push_ngu_coverage_mean[0] = 0
if 'hopper' in list_env and 'ngu' in list_alg : 
    hopper_ngu_coverage_mean[0] = 0
# lsd
if 'Easy' in list_env and 'lsd' in list_alg : 
    Easy_lsd_coverage_mean[0] = 0
if 'Ur' in list_env and 'lsd' in list_alg : 
    Ur_lsd_coverage_mean[0] = 0
if 'Hard' in list_env and 'lsd' in list_alg : 
    Hard_lsd_coverage_mean[0] = 0
if 'fetch' in list_env and 'lsd' in list_alg : 
    fetch_lsd_coverage_mean[0] = 0
if 'finger' in list_env and 'lsd' in list_alg : 
    finger_lsd_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'lsd' in list_alg : 
    fetch_push_lsd_coverage_mean[0] = 0
if 'hopper' in list_env and 'lsd' in list_alg : 
    hopper_lsd_coverage_mean[0] = 0
# csd
if 'Easy' in list_env and 'csd' in list_alg : 
    Easy_csd_coverage_mean[0] = 0
if 'Ur' in list_env and 'csd' in list_alg :
    Ur_csd_coverage_mean[0] = 0
if 'Hard' in list_env and 'csd' in list_alg :
    Hard_csd_coverage_mean[0] = 0
if 'fetch' in list_env and 'csd' in list_alg :
    fetch_csd_coverage_mean[0] = 0
if 'finger' in list_env and 'csd' in list_alg :
    finger_csd_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'csd' in list_alg :
    fetch_push_csd_coverage_mean[0] = 0
# metra
if 'Easy' in list_env and 'metra' in list_alg : 
    Easy_metra_coverage_mean[0] = 0
if 'Ur' in list_env and 'metra' in list_alg :
    Ur_metra_coverage_mean[0] = 0
if 'Hard' in list_env and 'metra' in list_alg :
    Hard_metra_coverage_mean[0] = 0
if 'fetch' in list_env and 'metra' in list_alg :
    fetch_metra_coverage_mean[0] = 0
if 'finger' in list_env and 'metra' in list_alg :
    finger_metra_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'metra' in list_alg :
    fetch_push_metra_coverage_mean[0] = 0
# smm
if 'Easy' in list_env and 'smm' in list_alg : 
    Easy_smm_coverage_mean[0] = 0
if 'Ur' in list_env and 'smm' in list_alg :
    Ur_smm_coverage_mean[0] = 0
if 'Hard' in list_env and 'smm' in list_alg :
    Hard_smm_coverage_mean[0] = 0
if 'fetch' in list_env and 'smm' in list_alg :
    fetch_smm_coverage_mean[0] = 0
if 'finger' in list_env and 'smm' in list_alg :
    finger_smm_coverage_mean[0] = 0
if 'fetch_push' in list_env and 'smm' in list_alg :
    fetch_push_smm_coverage_mean[0] = 0

# %%
# shapes 
# lds
Easy_lds_size = Easy_lds_coverage_mean.shape[0] if 'Easy' in list_env and 'lds' in list_alg  else None
Ur_lds_size = Ur_lds_coverage_mean.shape[0] if 'Ur' in list_env and 'lds' in list_alg  else None
Hard_lds_size = Hard_lds_coverage_mean.shape[0] if 'Hard' in list_env and 'lds' in list_alg  else None
fetch_lds_size = fetch_lds_coverage_mean.shape[0] if 'fetch' in list_env and 'lds' in list_alg  else None
finger_lds_size = finger_lds_coverage_mean.shape[0] if 'finger' in list_env and 'lds' in list_alg  else None
fetch_push_lds_size = fetch_push_lds_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'lds' in list_alg else None
hopper_lds_size = hopper_lds_coverage_mean.shape[0] if 'hopper' in list_env  and 'lds' in list_alg else None
# diayn
Easy_diayn_size = Easy_diayn_coverage_mean.shape[0] if 'Easy' in list_env  and 'diayn' in list_alg else None
Ur_diayn_size = Ur_diayn_coverage_mean.shape[0] if 'Ur' in list_env  and 'diayn' in list_alg else None
Hard_diayn_size = Hard_diayn_coverage_mean.shape[0] if 'Hard' in list_env  and 'diayn' in list_alg else None
fetch_diayn_size = fetch_diayn_coverage_mean.shape[0] if 'fetch' in list_env and 'diayn' in list_alg  else None
finger_diayn_size = finger_diayn_coverage_mean.shape[0] if 'finger' in list_env  and 'diayn' in list_alg else None
fetch_push_diayn_size = fetch_push_diayn_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'diayn' in list_alg else None
hopper_diayn_size = hopper_diayn_coverage_mean.shape[0] if 'hopper' in list_env  and 'diayn' in list_alg else None
# rnd
Easy_rnd_size = Easy_rnd_coverage_mean.shape[0] if 'Easy' in list_env and 'rnd' in list_alg  else None
Ur_rnd_size = Ur_rnd_coverage_mean.shape[0] if 'Ur' in list_env and 'rnd' in list_alg else None
Hard_rnd_size = Hard_rnd_coverage_mean.shape[0] if 'Hard' in list_env  and 'rnd' in list_alg else None
fetch_rnd_size = fetch_rnd_coverage_mean.shape[0] if 'fetch' in list_env  and 'rnd' in list_alg else None
finger_rnd_size = finger_rnd_coverage_mean.shape[0] if 'finger' in list_env and 'rnd' in list_alg  else None
fetch_push_rnd_size = fetch_push_rnd_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'rnd' in list_alg else None
hopper_rnd_size = hopper_rnd_coverage_mean.shape[0] if 'hopper' in list_env  and 'rnd' in list_alg else None
# ngu
Easy_ngu_size = Easy_ngu_coverage_mean.shape[0] if 'Easy' in list_env  and 'ngu' in list_alg else None
Ur_ngu_size = Ur_ngu_coverage_mean.shape[0] if 'Ur' in list_env  and 'ngu' in list_alg else None
Hard_ngu_size = Hard_ngu_coverage_mean.shape[0] if 'Hard' in list_env  and 'ngu' in list_alg else None
fetch_ngu_size = fetch_ngu_coverage_mean.shape[0] if 'fetch' in list_env  and 'ngu' in list_alg else None
finger_ngu_size = finger_ngu_coverage_mean.shape[0] if 'finger' in list_env and 'ngu' in list_alg  else None
fetch_push_ngu_size = fetch_push_ngu_coverage_mean.shape[0] if 'fetch_push' in list_env and 'ngu' in list_alg  else None
hopper_ngu_size = hopper_ngu_coverage_mean.shape[0] if 'hopper' in list_env  and 'ngu' in list_alg else None
# lsd
Easy_lsd_size = Easy_lsd_coverage_mean.shape[0] if 'Easy' in list_env  and 'lsd' in list_alg else None
Ur_lsd_size = Ur_lsd_coverage_mean.shape[0] if 'Ur' in list_env and 'lsd' in list_alg  else None
Hard_lsd_size = Hard_lsd_coverage_mean.shape[0] if 'Hard' in list_env  and 'lsd' in list_alg else None
fetch_lsd_size = fetch_lsd_coverage_mean.shape[0] if 'fetch' in list_env  and 'lsd' in list_alg else None
finger_lsd_size = finger_lsd_coverage_mean.shape[0] if 'finger' in list_env and 'lsd' in list_alg  else None
fetch_push_lsd_size = fetch_push_lsd_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'lsd' in list_alg else None
hopper_lsd_size = hopper_lsd_coverage_mean.shape[0] if 'hopper' in list_env  and 'lsd' in list_alg else None
# csd
Easy_csd_size = Easy_csd_coverage_mean.shape[0] if 'Easy' in list_env  and 'csd' in list_alg else None
Ur_csd_size = Ur_csd_coverage_mean.shape[0] if 'Ur' in list_env  and 'csd' in list_alg else None
Hard_csd_size = Hard_csd_coverage_mean.shape[0] if 'Hard' in list_env  and 'csd' in list_alg else None
fetch_csd_size = fetch_csd_coverage_mean.shape[0] if 'fetch' in list_env  and 'csd' in list_alg else None
finger_csd_size = finger_csd_coverage_mean.shape[0] if 'finger' in list_env and 'csd' in list_alg  else None
fetch_push_csd_size = fetch_push_csd_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'csd' in list_alg else None
# metra
Easy_metra_size = Easy_metra_coverage_mean.shape[0] if 'Easy' in list_env  and 'metra' in list_alg else None
Ur_metra_size = Ur_metra_coverage_mean.shape[0] if 'Ur' in list_env  and 'metra' in list_alg else None
Hard_metra_size = Hard_metra_coverage_mean.shape[0] if 'Hard' in list_env  and 'metra' in list_alg else None
fetch_metra_size = fetch_metra_coverage_mean.shape[0] if 'fetch' in list_env  and 'metra' in list_alg else None
finger_metra_size = finger_metra_coverage_mean.shape[0] if 'finger' in list_env and 'metra' in list_alg  else None
fetch_push_metra_size = fetch_push_metra_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'metra' in list_alg else None
# smm
Easy_smm_size = Easy_smm_coverage_mean.shape[0] if 'Easy' in list_env  and 'smm' in list_alg else None
Ur_smm_size = Ur_smm_coverage_mean.shape[0] if 'Ur' in list_env  and 'smm' in list_alg else None
Hard_smm_size = Hard_smm_coverage_mean.shape[0] if 'Hard' in list_env  and 'smm' in list_alg else None
fetch_smm_size = fetch_smm_coverage_mean.shape[0] if 'fetch' in list_env  and 'smm' in list_alg else None
finger_smm_size = finger_smm_coverage_mean.shape[0] if 'finger' in list_env and 'smm' in list_alg  else None
fetch_push_smm_size = fetch_push_smm_coverage_mean.shape[0] if 'fetch_push' in list_env  and 'smm' in list_alg else None

# %%
# nb_samples 
Easy_sample = 10**6
Ur_sample = 10**6
Hard_sample = 10**6
fetch_sample = 2*10**5
finger = 10**5
fetch_push_sample = 10**5

# %%
# x_axis 
# lds
Easy_lds_x_axis = np.linspace(0, Easy_sample, Easy_lds_size) if 'Easy' in list_env and 'lds' in list_alg  else None
Ur_lds_x_axis = np.linspace(0, Ur_sample, Ur_lds_size) if 'Ur' in list_env and 'lds' in list_alg  else None
Hard_lds_x_axis = np.linspace(0, Hard_sample, Hard_lds_size) if 'Hard' in list_env  and 'lds' in list_alg else None
fetch_lds_x_axis = np.linspace(0, fetch_sample, fetch_lds_size) if 'fetch' in list_env  and 'lds' in list_alg else None
finger_lds_x_axis = np.linspace(0, finger, finger_lds_size) if 'finger' in list_env and 'lds' in list_alg  else None
fetch_push_lds_x_axis = np.linspace(0, fetch_push_sample, fetch_push_lds_size) if 'fetch_push' in list_env  and 'lds' in list_alg else None
# diayn
Easy_diayn_x_axis = np.linspace(0, Easy_sample, Easy_diayn_size) if 'Easy' in list_env  and 'diayn' in list_alg else None
Ur_diayn_x_axis = np.linspace(0, Ur_sample, Ur_diayn_size) if 'Ur' in list_env and 'diayn' in list_alg  else None
Hard_diayn_x_axis = np.linspace(0, Hard_sample, Hard_diayn_size) if 'Hard' in list_env  and 'diayn' in list_alg else None
fetch_diayn_x_axis = np.linspace(0, fetch_sample, fetch_diayn_size) if 'fetch' in list_env and 'diayn' in list_alg  else None
finger_diayn_x_axis = np.linspace(0, finger, finger_diayn_size) if 'finger' in list_env and 'diayn' in list_alg  else None
fetch_push_diayn_x_axis = np.linspace(0, fetch_push_sample, fetch_push_diayn_size) if 'fetch_push' in list_env and 'diayn' in list_alg  else None
# rnd
Easy_rnd_x_axis = np.linspace(0, Easy_sample, Easy_rnd_size) if 'Easy' in list_env and 'rnd' in list_alg  else None
Ur_rnd_x_axis = np.linspace(0, Ur_sample, Ur_rnd_size) if 'Ur' in list_env and 'rnd' in list_alg  else None
Hard_rnd_x_axis = np.linspace(0, Hard_sample, Hard_rnd_size) if 'Hard' in list_env  and 'rnd' in list_alg else None
fetch_rnd_x_axis = np.linspace(0, fetch_sample, fetch_rnd_size) if 'fetch' in list_env  and 'rnd' in list_alg else None
finger_rnd_x_axis = np.linspace(0, finger, finger_rnd_size) if 'finger' in list_env  and 'rnd' in list_alg else None
fetch_push_rnd_x_axis = np.linspace(0, fetch_push_sample, fetch_push_rnd_size) if 'fetch_push' in list_env and 'rnd' in list_alg  else None
# ngu
Easy_ngu_x_axis = np.linspace(0, Easy_sample, Easy_ngu_size) if 'Easy' in list_env  and 'ngu' in list_alg else None
Ur_ngu_x_axis = np.linspace(0, Ur_sample, Ur_ngu_size) if 'Ur' in list_env and 'ngu' in list_alg  else None
Hard_ngu_x_axis = np.linspace(0, Hard_sample, Hard_ngu_size) if 'Hard' in list_env  and 'ngu' in list_alg else None
fetch_ngu_x_axis = np.linspace(0, fetch_sample, fetch_ngu_size) if 'fetch' in list_env  and 'ngu' in list_alg else None
finger_ngu_x_axis = np.linspace(0, finger, finger_ngu_size) if 'finger' in list_env  and 'ngu' in list_alg else None
fetch_push_ngu_x_axis = np.linspace(0, fetch_push_sample, fetch_push_ngu_size) if 'fetch_push' in list_env  and 'ngu' in list_alg else None
# lsd
Easy_lsd_x_axis = np.linspace(0, Easy_sample, Easy_lsd_size) if 'Easy' in list_env and 'lsd' in list_alg  else None
Ur_lsd_x_axis = np.linspace(0, Ur_sample, Ur_lsd_size) if 'Ur' in list_env and 'lsd' in list_alg  else None
Hard_lsd_x_axis = np.linspace(0, Hard_sample, Hard_lsd_size) if 'Hard' in list_env  and 'lsd' in list_alg else None
fetch_lsd_x_axis = np.linspace(0, fetch_sample, fetch_lsd_size) if 'fetch' in list_env and 'lsd' in list_alg  else None
finger_lsd_x_axis = np.linspace(0, finger, finger_lsd_size) if 'finger' in list_env  and 'lsd' in list_alg else None
fetch_push_lsd_x_axis = np.linspace(0, fetch_push_sample, fetch_push_lsd_size) if 'fetch_push' in list_env  and 'lsd' in list_alg else None
# csd
Easy_csd_x_axis = np.linspace(0, Easy_sample, Easy_csd_size) if 'Easy' in list_env  and 'csd' in list_alg else None
Ur_csd_x_axis = np.linspace(0, Ur_sample, Ur_csd_size) if 'Ur' in list_env  and 'csd' in list_alg else None
Hard_csd_x_axis = np.linspace(0, Hard_sample, Hard_csd_size) if 'Hard' in list_env  and 'csd' in list_alg else None
fetch_csd_x_axis = np.linspace(0, fetch_sample, fetch_csd_size) if 'fetch' in list_env  and 'csd' in list_alg else None
finger_csd_x_axis = np.linspace(0, finger, finger_csd_size) if 'finger' in list_env  and 'csd' in list_alg else None
fetch_push_csd_x_axis = np.linspace(0, fetch_push_sample, fetch_push_csd_size) if 'fetch_push' in list_env  and 'csd' in list_alg else None
# metra
Easy_metra_x_axis = np.linspace(0, Easy_sample, Easy_metra_size) if 'Easy' in list_env  and 'metra' in list_alg else None
Ur_metra_x_axis = np.linspace(0, Ur_sample, Ur_metra_size) if 'Ur' in list_env  and 'metra' in list_alg else None
Hard_metra_x_axis = np.linspace(0, Hard_sample, Hard_metra_size) if 'Hard' in list_env  and 'metra' in list_alg else None
fetch_metra_x_axis = np.linspace(0, fetch_sample, fetch_metra_size) if 'fetch' in list_env  and 'metra' in list_alg else None
finger_metra_x_axis = np.linspace(0, finger, finger_metra_size) if 'finger' in list_env  and 'metra' in list_alg else None
fetch_push_metra_x_axis = np.linspace(0, fetch_push_sample, fetch_push_metra_size) if 'fetch_push' in list_env  and 'metra' in list_alg else None
# smm
Easy_smm_x_axis = np.linspace(0, Easy_sample, Easy_smm_size) if 'Easy' in list_env  and 'smm' in list_alg else None
Ur_smm_x_axis = np.linspace(0, Ur_sample, Ur_smm_size) if 'Ur' in list_env  and 'smm' in list_alg else None
Hard_smm_x_axis = np.linspace(0, Hard_sample, Hard_smm_size) if 'Hard' in list_env  and 'smm' in list_alg else None
fetch_smm_x_axis = np.linspace(0, fetch_sample, fetch_smm_size) if 'fetch' in list_env  and 'smm' in list_alg else None
finger_smm_x_axis = np.linspace(0, finger, finger_smm_size) if 'finger' in list_env  and 'smm' in list_alg else None
fetch_push_smm_x_axis = np.linspace(0, fetch_push_sample, fetch_push_smm_size) if 'fetch_push' in list_env  and 'smm' in list_alg else None

# %%
colors = {'LEADSSS': 'tab:blue', 'DIAYN': 'tab:orange', 'RND': 'tab:green', 'NGU': 'tab:red', 'LSD': 'tab:purple', 'CSD': 'tab:brown', 'METRA' : 'tab:pink', 'SMM': 'tab:gray'}

# %%
# Easy
Easy_fig = plt.figure(figsize=(4, 4))
Easy_ax = Easy_fig.add_subplot(111)
Easy_ax.set_title('Easy', fontsize=15)
# Easy_ax.set_xlabel(r'$\times 10^3$')
# Easy_ax.set_ylabel('Coverage')
# seaborn style
sns.set(style="whitegrid")
# plot
# lds
plt.plot(Easy_lds_x_axis, Easy_lds_coverage_mean, label='LEADSSS', color=colors['LEADSSS'])
plt.fill_between(Easy_lds_x_axis, Easy_lds_coverage_mean - Easy_lds_coverage_std, Easy_lds_coverage_mean + Easy_lds_coverage_std, alpha=0.3, color=colors['LEADSSS'])
# diayn
plt.plot(Easy_diayn_x_axis, Easy_diayn_coverage_mean, label='DIAYN', color=colors['DIAYN'])
plt.fill_between(Easy_diayn_x_axis, Easy_diayn_coverage_mean - Easy_diayn_coverage_std, Easy_diayn_coverage_mean + Easy_diayn_coverage_std, alpha=0.3, color=colors['DIAYN'])
# rnd
plt.plot(Easy_rnd_x_axis, Easy_rnd_coverage_mean, label='RND', color=colors['RND'])
plt.fill_between(Easy_rnd_x_axis, Easy_rnd_coverage_mean - Easy_rnd_coverage_std, Easy_rnd_coverage_mean + Easy_rnd_coverage_std, alpha=0.3, color=colors['RND'])
# ngu
plt.plot(Easy_ngu_x_axis, Easy_ngu_coverage_mean, label='NGU', color=colors['NGU'])
plt.fill_between(Easy_ngu_x_axis, Easy_ngu_coverage_mean - Easy_ngu_coverage_std, Easy_ngu_coverage_mean + Easy_ngu_coverage_std, alpha=0.3, color=colors['NGU'])
# lsd
plt.plot(Easy_lsd_x_axis, Easy_lsd_coverage_mean, label='LSD', color=colors['LSD'])
plt.fill_between(Easy_lsd_x_axis, Easy_lsd_coverage_mean - Easy_lsd_coverage_std, Easy_lsd_coverage_mean + Easy_lsd_coverage_std, alpha=0.3, color=colors['LSD'])
# CSD
plt.plot(Easy_csd_x_axis, Easy_csd_coverage_mean, label='CSD', color=colors['CSD'])
plt.fill_between(Easy_csd_x_axis, Easy_csd_coverage_mean - Easy_csd_coverage_std, Easy_csd_coverage_mean + Easy_csd_coverage_std, alpha=0.3, color=colors['CSD'])
# METRA
plt.plot(Easy_metra_x_axis, Easy_metra_coverage_mean, label='METRA', color=colors['METRA'])
plt.fill_between(Easy_metra_x_axis, Easy_metra_coverage_mean - Easy_metra_coverage_std, Easy_metra_coverage_mean + Easy_metra_coverage_std, alpha=0.3, color=colors['METRA'])
# SMM
plt.plot(Easy_smm_x_axis, Easy_smm_coverage_mean, label='SMM', color=colors['SMM'])
plt.fill_between(Easy_smm_x_axis, Easy_smm_coverage_mean - Easy_smm_coverage_std, Easy_smm_coverage_mean + Easy_smm_coverage_std, alpha=0.3, color=colors['SMM'])
# CIC

# plt.legend()
plt.tight_layout()
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1)) 
Easy_ax.xaxis.set_major_formatter(formatter)
# limit y 
plt.ylim(0, 101)
# plt.xlim(-10, 10**6)
plt.xlim(-10**4, 10**6)
plt.savefig('figures/Easy.pdf')

# %%
# Ur
Ur_fig = plt.figure(figsize=(4, 4))
Ur_ax = Ur_fig.add_subplot(111)
Ur_ax.set_title('Umaze', fontsize=15)
# Ur_ax.set_xlabel(r'$\times 10^3$')
# Ur_ax.set_ylabel('Coverage')
# seaborn style
sns.set(style="whitegrid")
# plot
# lds
plt.plot(Ur_lds_x_axis, Ur_lds_coverage_mean, label='LEADSSS', color=colors['LEADSSS'])
plt.fill_between(Ur_lds_x_axis, Ur_lds_coverage_mean - Ur_lds_coverage_std, Ur_lds_coverage_mean + Ur_lds_coverage_std, alpha=0.3, color=colors['LEADSSS'])
# diayn
plt.plot(Ur_diayn_x_axis, Ur_diayn_coverage_mean, label='DIAYN', color=colors['DIAYN'])
plt.fill_between(Ur_diayn_x_axis, Ur_diayn_coverage_mean - Ur_diayn_coverage_std, Ur_diayn_coverage_mean + Ur_diayn_coverage_std, alpha=0.3, color=colors['DIAYN'])
# rnd
plt.plot(Ur_rnd_x_axis, Ur_rnd_coverage_mean, label='RND', color=colors['RND'])
plt.fill_between(Ur_rnd_x_axis, Ur_rnd_coverage_mean - Ur_rnd_coverage_std, Ur_rnd_coverage_mean + Ur_rnd_coverage_std, alpha=0.3, color=colors['RND'])
# ngu
plt.plot(Ur_ngu_x_axis, Ur_ngu_coverage_mean, label='NGU', color=colors['NGU'])
plt.fill_between(Ur_ngu_x_axis, Ur_ngu_coverage_mean - Ur_ngu_coverage_std, Ur_ngu_coverage_mean + Ur_ngu_coverage_std, alpha=0.3, color=colors['NGU'])
# lsd
plt.plot(Ur_lsd_x_axis, Ur_lsd_coverage_mean, label='LSD', color=colors['LSD'])
plt.fill_between(Ur_lsd_x_axis, Ur_lsd_coverage_mean - Ur_lsd_coverage_std, Ur_lsd_coverage_mean + Ur_lsd_coverage_std, alpha=0.3, color=colors['LSD'])
# CSD
plt.plot(Ur_csd_x_axis, Ur_csd_coverage_mean, label='CSD', color=colors['CSD'])
plt.fill_between(Ur_csd_x_axis, Ur_csd_coverage_mean - Ur_csd_coverage_std, Ur_csd_coverage_mean + Ur_csd_coverage_std, alpha=0.3, color=colors['CSD'])
# METRA
plt.plot(Ur_metra_x_axis, Ur_metra_coverage_mean, label='METRA', color=colors['METRA'])
plt.fill_between(Ur_metra_x_axis, Ur_metra_coverage_mean - Ur_metra_coverage_std, Ur_metra_coverage_mean + Ur_metra_coverage_std, alpha=0.3, color=colors['METRA'])
# SMM
plt.plot(Ur_smm_x_axis, Ur_smm_coverage_mean, label='SMM', color=colors['SMM'])
plt.fill_between(Ur_smm_x_axis, Ur_smm_coverage_mean - Ur_smm_coverage_std, Ur_smm_coverage_mean + Ur_smm_coverage_std, alpha=0.3, color=colors['SMM'])
# CIC

# plt.legend()
# limit y 
plt.ylim(0, 101)
# plt.xlim(-10, 10**6)
plt.xlim(-10**4, 10**6)
plt.tight_layout()
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1)) 
Ur_ax.xaxis.set_major_formatter(formatter)

plt.savefig('figures/Ur.pdf')

# %%
# Hard
Hard_fig = plt.figure(figsize=(4, 4))
Hard_ax = Hard_fig.add_subplot(111)
Hard_ax.set_title('Hard', fontsize=14)
# Hard_ax.set_xlabel(r'$\times 10^3$')
# Hard_ax.set_ylabel('Coverage')
# seaborn style
sns.set(style="whitegrid")
# plot
# lds
plt.plot(Hard_lds_x_axis, Hard_lds_coverage_mean, label='LEADSSS', color=colors['LEADSSS'])
plt.fill_between(Hard_lds_x_axis, Hard_lds_coverage_mean - Hard_lds_coverage_std, Hard_lds_coverage_mean + Hard_lds_coverage_std, alpha=0.3, color=colors['LEADSSS'])
# diayn
plt.plot(Hard_diayn_x_axis, Hard_diayn_coverage_mean, label='DIAYN', color=colors['DIAYN'])
plt.fill_between(Hard_diayn_x_axis, Hard_diayn_coverage_mean - Hard_diayn_coverage_std, Hard_diayn_coverage_mean + Hard_diayn_coverage_std, alpha=0.3, color=colors['DIAYN'])
# rnd
plt.plot(Hard_rnd_x_axis, Hard_rnd_coverage_mean, label='RND', color=colors['RND'])
plt.fill_between(Hard_rnd_x_axis, Hard_rnd_coverage_mean - Hard_rnd_coverage_std, Hard_rnd_coverage_mean + Hard_rnd_coverage_std, alpha=0.3, color=colors['RND'])
# ngu
plt.plot(Hard_ngu_x_axis, Hard_ngu_coverage_mean, label='NGU', color=colors['NGU'])
plt.fill_between(Hard_ngu_x_axis, Hard_ngu_coverage_mean - Hard_ngu_coverage_std, Hard_ngu_coverage_mean + Hard_ngu_coverage_std, alpha=0.3, color=colors['NGU'])
# lsd
plt.plot(Hard_lsd_x_axis, Hard_lsd_coverage_mean, label='LSD', color=colors['LSD'])
plt.fill_between(Hard_lsd_x_axis, Hard_lsd_coverage_mean - Hard_lsd_coverage_std, Hard_lsd_coverage_mean + Hard_lsd_coverage_std, alpha=0.3, color=colors['LSD'])
# CSD
plt.plot(Hard_csd_x_axis, Hard_csd_coverage_mean, label='CSD', color=colors['CSD'])
plt.fill_between(Hard_csd_x_axis, Hard_csd_coverage_mean - Hard_csd_coverage_std, Hard_csd_coverage_mean + Hard_csd_coverage_std, alpha=0.3, color=colors['CSD'])
# METRA
plt.plot(Hard_metra_x_axis, Hard_metra_coverage_mean, label='METRA', color=colors['METRA'])
plt.fill_between(Hard_metra_x_axis, Hard_metra_coverage_mean - Hard_metra_coverage_std, Hard_metra_coverage_mean + Hard_metra_coverage_std, alpha=0.3, color=colors['METRA'])
# SMM
plt.plot(Hard_smm_x_axis, Hard_smm_coverage_mean, label='SMM', color=colors['SMM'])
plt.fill_between(Hard_smm_x_axis, Hard_smm_coverage_mean - Hard_smm_coverage_std, Hard_smm_coverage_mean + Hard_smm_coverage_std, alpha=0.3, color=colors['SMM'])
# CIC


# plt.legend()
plt.tight_layout()
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1)) 
Hard_ax.xaxis.set_major_formatter(formatter)
# limit y 
plt.xlim(-10000, 10**6)
plt.ylim(0, 101)
# plt.xlim(0, 500)
plt.savefig('figures/Hard.pdf')

# %%
# fetch reach
fetch_fig = plt.figure(figsize=(4, 4))
fetch_ax = fetch_fig.add_subplot(111)
fetch_ax.set_title('Fetch Reach', fontsize=14)
# fetch_ax.set_xlabel(r'$\times 10^3$')
# fetch_ax.set_ylabel('Coverage')
# seaborn style
sns.set(style="whitegrid")
# plot
# lds
std_frac= 1.0
mean_mult = 1.0

plt.plot(fetch_lds_x_axis, fetch_lds_coverage_mean*mean_mult, label='LEADSSS', color=colors['LEADSSS'])
plt.fill_between(fetch_lds_x_axis, fetch_lds_coverage_mean*mean_mult - fetch_lds_coverage_std/std_frac, fetch_lds_coverage_mean*mean_mult + fetch_lds_coverage_std/std_frac, alpha=0.3, color=colors['LEADSSS'])
# diayn
plt.plot(fetch_diayn_x_axis, fetch_diayn_coverage_mean*mean_mult, label='DIAYN', color=colors['DIAYN'])
plt.fill_between(fetch_diayn_x_axis, fetch_diayn_coverage_mean*mean_mult - fetch_diayn_coverage_std/std_frac, fetch_diayn_coverage_mean*mean_mult + fetch_diayn_coverage_std/std_frac, alpha=0.3, color=colors['DIAYN'])
# rnd
plt.plot(fetch_rnd_x_axis, fetch_rnd_coverage_mean*mean_mult, label='RND', color=colors['RND'])
plt.fill_between(fetch_rnd_x_axis, fetch_rnd_coverage_mean*mean_mult - fetch_rnd_coverage_std/std_frac, fetch_rnd_coverage_mean*mean_mult + fetch_rnd_coverage_std/std_frac, alpha=0.3, color=colors['RND'])
# ngu
plt.plot(fetch_ngu_x_axis, fetch_ngu_coverage_mean*mean_mult, label='NGU', color=colors['NGU'])
plt.fill_between(fetch_ngu_x_axis, fetch_ngu_coverage_mean*mean_mult - fetch_ngu_coverage_std/std_frac, fetch_ngu_coverage_mean*mean_mult + fetch_ngu_coverage_std/std_frac, alpha=0.3, color=colors['NGU'])
# lsd
plt.plot(fetch_lsd_x_axis, fetch_lsd_coverage_mean*mean_mult, label='LSD', color=colors['LSD'])
plt.fill_between(fetch_lsd_x_axis, fetch_lsd_coverage_mean*mean_mult - fetch_lsd_coverage_std/std_frac, fetch_lsd_coverage_mean*mean_mult + fetch_lsd_coverage_std/std_frac, alpha=0.3, color=colors['LSD'])
# csd
plt.plot(fetch_csd_x_axis, fetch_csd_coverage_mean*mean_mult, label='CSD', color=colors['CSD'])
plt.fill_between(fetch_csd_x_axis, fetch_csd_coverage_mean*mean_mult - fetch_csd_coverage_std/std_frac, fetch_csd_coverage_mean*mean_mult + fetch_csd_coverage_std/std_frac, alpha=0.3, color=colors['CSD'])
# metra
plt.plot(fetch_metra_x_axis, fetch_metra_coverage_mean*mean_mult, label='METRA', color=colors['METRA'])
plt.fill_between(fetch_metra_x_axis, fetch_metra_coverage_mean*mean_mult - fetch_metra_coverage_std/std_frac, fetch_metra_coverage_mean*mean_mult + fetch_metra_coverage_std/std_frac, alpha=0.3, color=colors['METRA'])
# smm
plt.plot(fetch_smm_x_axis, fetch_smm_coverage_mean*mean_mult, label='SMM', color=colors['SMM'])
plt.fill_between(fetch_smm_x_axis, fetch_smm_coverage_mean*mean_mult - fetch_smm_coverage_std/std_frac, fetch_smm_coverage_mean*mean_mult + fetch_smm_coverage_std/std_frac, alpha=0.3, color=colors['SMM'])

# plt.legend()
plt.tight_layout()
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1)) 
fetch_ax.xaxis.set_major_formatter(formatter)
# limit y
plt.ylim(0, 101)
plt.xlim(-10, 2*10**5)
plt.savefig('figures/fetch_reach.pdf')

# %%
# finger
finger_fig = plt.figure(figsize=(4, 4))
finger_ax = finger_fig.add_subplot(111)
finger_ax.set_title('Finger', fontsize=14)
# finger_ax.set_xlabel(r'$\times 10^3$')
# finger_ax.set_ylabel('Coverage')
# seaborn style
sns.set(style="whitegrid")
std_frac= 1.0
mean_mult = 1.0
# plot
# lds
plt.plot(finger_lds_x_axis, finger_lds_coverage_mean, label='LEADSSS', color=colors['LEADSSS'])
plt.fill_between(finger_lds_x_axis, finger_lds_coverage_mean - finger_lds_coverage_std*std_frac, finger_lds_coverage_mean + finger_lds_coverage_std*std_frac, alpha=0.3, color=colors['LEADSSS'])
# diayn
plt.plot(finger_diayn_x_axis, finger_diayn_coverage_mean, label='DIAYN', color=colors['DIAYN'])
plt.fill_between(finger_diayn_x_axis, finger_diayn_coverage_mean - finger_diayn_coverage_std*std_frac, finger_diayn_coverage_mean + finger_diayn_coverage_std*std_frac, alpha=0.3, color=colors['DIAYN'])
# rnd
plt.plot(finger_rnd_x_axis, finger_rnd_coverage_mean, label='RND', color=colors['RND'])
plt.fill_between(finger_rnd_x_axis, finger_rnd_coverage_mean - finger_rnd_coverage_std*std_frac, finger_rnd_coverage_mean + finger_rnd_coverage_std*std_frac, alpha=0.3, color=colors['RND'])
# ngu
plt.plot(finger_ngu_x_axis, finger_ngu_coverage_mean, label='NGU', color=colors['NGU'])
plt.fill_between(finger_ngu_x_axis, finger_ngu_coverage_mean - finger_ngu_coverage_std*std_frac, finger_ngu_coverage_mean + finger_ngu_coverage_std*std_frac, alpha=0.3, color=colors['NGU'])
# lsd
plt.plot(finger_lsd_x_axis, finger_lsd_coverage_mean, label='LSD', color=colors['LSD'])
plt.fill_between(finger_lsd_x_axis, finger_lsd_coverage_mean - finger_lsd_coverage_std*std_frac, finger_lsd_coverage_mean + finger_lsd_coverage_std*std_frac, alpha=0.3, color=colors['LSD'])
# csd
plt.plot(finger_csd_x_axis, finger_csd_coverage_mean, label='CSD', color=colors['CSD'])
plt.fill_between(finger_csd_x_axis, finger_csd_coverage_mean - finger_csd_coverage_std*std_frac, finger_csd_coverage_mean + finger_csd_coverage_std*std_frac, alpha=0.3, color=colors['CSD'])
# metra
plt.plot(finger_metra_x_axis, finger_metra_coverage_mean, label='METRA', color=colors['METRA'])
plt.fill_between(finger_metra_x_axis, finger_metra_coverage_mean - finger_metra_coverage_std*std_frac, finger_metra_coverage_mean + finger_metra_coverage_std*std_frac, alpha=0.3, color=colors['METRA'])
# smm
plt.plot(finger_smm_x_axis, finger_smm_coverage_mean, label='SMM', color=colors['SMM'])
plt.fill_between(finger_smm_x_axis, finger_smm_coverage_mean - finger_smm_coverage_std*std_frac, finger_smm_coverage_mean + finger_smm_coverage_std*std_frac, alpha=0.3, color=colors['SMM'])
# cic
# plt.legend()
plt.tight_layout()
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1)) 
finger_ax.xaxis.set_major_formatter(formatter)
# limit y
plt.ylim(0, 101)
plt.xlim(-10, 10**5)
plt.savefig('figures/finger.pdf')

# %%
# fetch push
fetch_push_fig = plt.figure(figsize=(4, 4))
fetch_push_ax = fetch_push_fig.add_subplot(111)
fetch_push_ax.set_title('Fetch Slide', fontsize=14)
# fetch_push_ax.set_xlabel(r'$\times 10^3$')
# fetch_push_ax.set_ylabel('Coverage')
# seaborn style
sns.set(style="whitegrid")
# plot
std_frac= 1.0
mean_mult = 1.0
# lds
plt.plot(fetch_push_lds_x_axis, fetch_push_lds_coverage_mean*mean_mult, label='LEADSSS', color=colors['LEADSSS'])
plt.fill_between(fetch_push_lds_x_axis, fetch_push_lds_coverage_mean*mean_mult - fetch_push_lds_coverage_std*std_frac, fetch_push_lds_coverage_mean*mean_mult + fetch_push_lds_coverage_std*std_frac, alpha=0.3, color=colors['LEADSSS'])
# diayn
plt.plot(fetch_push_diayn_x_axis, fetch_push_diayn_coverage_mean*mean_mult, label='DIAYN', color=colors['DIAYN'])
plt.fill_between(fetch_push_diayn_x_axis, fetch_push_diayn_coverage_mean*mean_mult - fetch_push_diayn_coverage_std*std_frac, fetch_push_diayn_coverage_mean*mean_mult + fetch_push_diayn_coverage_std*std_frac, alpha=0.3, color=colors['DIAYN'])
# rnd
plt.plot(fetch_push_rnd_x_axis, fetch_push_rnd_coverage_mean*mean_mult, label='RND', color=colors['RND'])
plt.fill_between(fetch_push_rnd_x_axis, fetch_push_rnd_coverage_mean*mean_mult - fetch_push_rnd_coverage_std*std_frac, fetch_push_rnd_coverage_mean*mean_mult + fetch_push_rnd_coverage_std*std_frac, alpha=0.3, color=colors['RND'])
# ngu
plt.plot(fetch_push_ngu_x_axis, fetch_push_ngu_coverage_mean*mean_mult, label='NGU', color=colors['NGU'])
plt.fill_between(fetch_push_ngu_x_axis, fetch_push_ngu_coverage_mean*mean_mult - fetch_push_ngu_coverage_std*std_frac, fetch_push_ngu_coverage_mean*mean_mult + fetch_push_ngu_coverage_std*std_frac, alpha=0.3, color=colors['NGU'])
# lsd
plt.plot(fetch_push_lsd_x_axis, fetch_push_lsd_coverage_mean*mean_mult, label='LSD', color=colors['LSD'])
plt.fill_between(fetch_push_lsd_x_axis, fetch_push_lsd_coverage_mean*mean_mult - fetch_push_lsd_coverage_std*std_frac, fetch_push_lsd_coverage_mean*mean_mult + fetch_push_lsd_coverage_std*std_frac, alpha=0.3, color=colors['LSD'])
# csd
plt.plot(fetch_push_csd_x_axis, fetch_push_csd_coverage_mean*mean_mult, label='CSD', color=colors['CSD'])
plt.fill_between(fetch_push_csd_x_axis, fetch_push_csd_coverage_mean*mean_mult - fetch_push_csd_coverage_std*std_frac, fetch_push_csd_coverage_mean*mean_mult + fetch_push_csd_coverage_std*std_frac, alpha=0.3, color=colors['CSD'])
# metra
plt.plot(fetch_push_metra_x_axis, fetch_push_metra_coverage_mean*mean_mult, label='METRA', color=colors['METRA'])
plt.fill_between(fetch_push_metra_x_axis, fetch_push_metra_coverage_mean*mean_mult - fetch_push_metra_coverage_std*std_frac, fetch_push_metra_coverage_mean*mean_mult + fetch_push_metra_coverage_std*std_frac, alpha=0.3, color=colors['METRA'])
# smm
plt.plot(fetch_push_smm_x_axis, fetch_push_smm_coverage_mean*mean_mult, label='SMM', color=colors['SMM'])
plt.fill_between(fetch_push_smm_x_axis, fetch_push_smm_coverage_mean*mean_mult - fetch_push_smm_coverage_std*std_frac, fetch_push_smm_coverage_mean*mean_mult + fetch_push_smm_coverage_std*std_frac, alpha=0.3, color=colors['SMM'])
# cic
# plt.legend()
plt.tight_layout()
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1)) 
fetch_push_ax.xaxis.set_major_formatter(formatter)
# limit y
plt.ylim(0, 101)
plt.xlim(-10, 10**5)
plt.savefig('figures/fetch_slide.pdf')

# %%
# legend
import matplotlib.lines as mlines
line1 = mlines.Line2D([], [], color=colors['LEADSSS'], label='LEADS')
line2 = mlines.Line2D([], [], color=colors['NGU'], label='NGU')
line3 = mlines.Line2D([], [], color=colors['RND'], label='RND')
line4 = mlines.Line2D([], [], color=colors['DIAYN'], label='DIAYN')
line5 = mlines.Line2D([], [], color=colors['LSD'], label='LSD')
line6 = mlines.Line2D([], [], color=colors['CSD'], label='CSD')
line7 = mlines.Line2D([], [], color=colors['METRA'], label='METRA')
line8 = mlines.Line2D([], [], color=colors['SMM'], label='SMM')



# Création d'une nouvelle figure pour la légende
fig_leg, ax_leg = plt.subplots(figsize=(1, 1))
ax_leg.axis('off')  # Masquer les axes
ax_leg.legend(handles=[line1, line2, line3, line4, line5, line6, line7, line8], loc='center')
plt.tight_layout()
plt.savefig('figures/legend.pdf', bbox_inches='tight', pad_inches=0)
# Out:
# <ipython-input-27-d19293a1afa2>:18: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# legend skills 
skill_colors = ['r', 'g', 'b', 'y', 'm', 'c', 'k', 'w']

# create legend
skill_legend = []
for i in range(6):
    # dots 
    skill_legend.append(mlines.Line2D([], [], color=skill_colors[i], marker='o', linestyle='None', markersize=10, label='Skill {}'.format(i)))
fig_leg, ax_leg = plt.subplots(figsize=(1, 1))
ax_leg.axis('off')  # Masquer les axes
ax_leg.legend(handles=skill_legend, loc='center')
plt.tight_layout()
plt.savefig('figures/skill_legend.pdf', bbox_inches='tight', pad_inches=0)

# %%
# legend skills horizontal
skill_legend = []
for i in range(6):
    # dots 
    skill_legend.append(mlines.Line2D([], [], color=skill_colors[i], marker='o', linestyle='None', markersize=10, label='Skill {}'.format(i)))
fig_leg, ax_leg = plt.subplots(figsize=(1, 1))
ax_leg.axis('off')  # Masquer les axes
# masquer l'encadré de la légende
ax_leg.legend(handles=skill_legend, loc='center', ncol=6, frameon=False)
plt.tight_layout()
plt.savefig('figures/skill_legend_horizontal.pdf', bbox_inches='tight', pad_inches=0)
# Out:
# <ipython-input-14-5295b84450b6>:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
from matplotlib import cm
# skill label with rainbow color
n_skill = 12
colors = cm.rainbow(np.linspace(0, 1, n_skill))
# create legend
skill_legend = []
for i in range(n_skill):
    # dots 
    skill_legend.append(mlines.Line2D([], [], color=colors[i], marker='o', linestyle='None', markersize=10, label='Skill {}'.format(i)))
fig_leg, ax_leg = plt.subplots(figsize=(1, 1))
ax_leg.axis('off')  # Masquer les axes
ax_leg.legend(handles=skill_legend, loc='center')
plt.tight_layout()
plt.savefig('figures/skill_legend_rainbow.pdf', bbox_inches='tight', pad_inches=0)
# Out:
# <ipython-input-87-261b44811cf7>:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
